# %% [markdown]
# # Matplotlib Exercises

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(5, 15, 10)
y = 4 * x**2

# %%
fig = plt.figure()

ax1 = fig.add_axes([0.1, 0.1, 1.0, 0.33]) # main 
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.33]) # inset add relative positions in figure
#ax3 = fig.add_axes([0.2, 0.5, 0.4, 0.3])
#ax4 = fig.add_axes([0.2, 0.5, 0.4, 0.3])
#ax5 = fig.add_axes([0.2, 0.5, 0.4, 0.3])
#ax5 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

ax1.plot(x, y, 'b')
ax1.set_xlabel('eje X')
ax1.set_ylabel('eje Y')
ax1.set_title('titulo principal')

ax2.plot(y, x, 'r')
ax2.set_xlabel('eje X2')
ax2.set_ylabel('eje Y2')
ax2.set_title('titulo');

# %%
x1 = np.linspace(5, 15, 10)
x2 = np.linspace(5, 15, 20)

y1 = 4 * x1**2
y2 = x2**3

# %%
plt.subplot(1,2,1)
plt.plot(x1, y1, 'or--') # More on color options later
plt.subplot(1,2,2)
plt.plot(y2, x2, 'k*-');
#plt.subplot(1,2,2)
#plt.plot(y2, x2, 'k*-');
#plt.subplot(1,2,3)
#
#plt.plot(y2, x2, 'k*-');

# %%
figure, axis = plt.subplots(3, 3)
#axis[0, 0].plot(x1, x1)

# %%
plt.figure(figsize=(12, 12))

#ax4 = plt.subplot(2,1,2)
ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)
ax5 = plt.subplot(2,1,2)
#ax6 = plt.subplot(2,1,2)
#ax7 = plt.subplot(2,1,2)
#ax8 = plt.subplot(2,1,2)
#ax9 = plt.subplot(2,1,2)
axes = [ax1, ax2, ax3, ax4]

# %% [markdown]
# ### Last test

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some fake data.
x1 = np.linspace(0.0, 5.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
x2 = np.linspace(0.0, 2.0)
y2 = np.cos(2 * np.pi * x2)

# %%
fig, ax = plt.subplots(3, 2)
fig.suptitle('A tale of 2 subplots')

ax[0,0].plot(x1, y1, 'o-')
ax[0,0].set_ylabel('Damped oscillation')

ax[1].plot(x2, y2, '.-')
ax[1].set_xlabel('time (s)')
ax[1].set_ylabel('Undamped')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_382/1582989106.py in <module>
#       5 ax[0,0].set_ylabel('Damped oscillation')
#       6
# ----> 7 ax[1].plot(x2, y2, '.-')
#       8 ax[1].set_xlabel('time (s)')
#       9 ax[1].set_ylabel('Undamped')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
plt.figure(figsize=(12, 6))

ax = plt.subplot(3,1,1)
ax5 = plt.subplot(3,2,3)
ax1 = plt.subplot(3,4,7)
ax2 = plt.subplot(3,4,9)
ax3 = plt.subplot(3,4,10)
ax4 = plt.subplot(3,4,11)

#ax3 = plt.subplot(3,2,)
#ax4 = plt.subplot(3,2,4)
#ax5 = plt.subplot(3,3,5)
#ax5 = plt.subplot(3,3,5)
#ax5 = plt.subplot(3,3,5)
#ax4 = plt.subplot()



#ax4 = plt.subplot(3,3,2)
#ax6 = plt.subplot(3,3,2)
#ax7 = plt.subplot(3,3,2)
#ax5 = plt.subplot(3,1,3)
#axes = [ax1, ax2, ax3, ax4]

# %%
# ?plt.subplot

# %%
plt.figure(figsize=(20, 6))

ax = plt.subplot(3,2,1)
ax5 = plt.subplot(3,3,4)
ax1 = plt.subplot(3,6,9)
ax2 = plt.subplot(3,6,13)
ax3 = plt.subplot(3,6,14)
ax4 = plt.subplot(3,6,15)

#ax3 = plt.subplot(3,2,)
#ax4 = plt.subplot(3,2,4)
#ax5 = plt.subplot(3,3,5)
#ax5 = plt.subplot(3,3,5)
#ax5 = plt.subplot(3,3,5)
#ax4 = plt.subplot()



#ax4 = plt.subplot(3,3,2)
#ax6 = plt.subplot(3,3,2)
#ax7 = plt.subplot(3,3,2)
#ax5 = plt.subplot(3,1,3)
#axes = [ax1, ax2, ax3, ax4]

# %%
plt.figure(figsize=(12, 6))

ax = plt.subplot(3,4,1)
ax5 = plt.subplot(3,3,4)
ax1 = plt.subplot(3,6,9)
ax2 = plt.subplot(3,6,13)
ax3 = plt.subplot(3,6,14)
ax4 = plt.subplot(3,6,15)

#ax3 = plt.subplot(3,2,)
#ax4 = plt.subplot(3,2,4)
#ax5 = plt.subplot(3,3,5)
#ax5 = plt.subplot(3,3,5)
#ax5 = plt.subplot(3,3,5)
#ax4 = plt.subplot()



#ax4 = plt.subplot(3,3,2)
#ax6 = plt.subplot(3,3,2)
#ax7 = plt.subplot(3,3,2)
#ax5 = plt.subplot(3,1,3)
#axes = [ax1, ax2, ax3, ax4]
