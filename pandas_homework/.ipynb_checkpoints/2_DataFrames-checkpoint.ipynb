# %% [markdown]
# ## **DataFrame:**
#
# Estructura (objeto) multivariable con indexación integrada. _Tabla_
#
# Conjunto de Series

# %%
import pandas as pd
import numpy as np

# %%
valores = [['Ana', 18, 0.5], ['Luis', 22, 0.33], ['Carmen', 20, 0.85]]
columnas = ['Nombre', 'Edad', 'Otro']
filas = ['a', 'b', 'c']

df = pd.DataFrame(data=valores, index=filas, columns=columnas)
df
# Out:
#    Nombre  Edad  Otro
# a     Ana    18  0.50
# b    Luis    22  0.33
# c  Carmen    20  0.85

# %%
nums = np.random.randint(100, 3000, (20, 4))
letters = np.reshape(list("abcd")*5, (20,1))

values = np.append(nums, letters, axis = 1)
values
# Out:
# array([['2138', '701', '2557', '2560', 'a'],
#        ['185', '1807', '2973', '2346', 'b'],
#        ['685', '417', '389', '148', 'c'],
#        ['1328', '187', '2552', '1707', 'd'],
#        ['2717', '2426', '418', '836', 'a'],
#        ['1771', '2006', '2394', '1888', 'b'],
#        ['2092', '695', '469', '991', 'c'],
#        ['2755', '122', '1447', '1644', 'd'],
#        ['2304', '2451', '1875', '1082', 'a'],
#        ['1490', '1231', '2758', '336', 'b'],
#        ['2855', '1473', '2834', '2369', 'c'],
#        ['426', '2874', '1081', '2269', 'd'],
#        ['2893', '1889', '2140', '315', 'a'],
#        ['1265', '1680', '130', '2103', 'b'],
#        ['2569', '2232', '503', '2323', 'c'],
#        ['1638', '855', '1835', '2192', 'd'],
#        ['2370', '2131', '614', '1391', 'a'],
#        ['2636', '2756', '1602', '1417', 'b'],
#        ['2205', '2120', '987', '120', 'c'],
#        ['1871', '2981', '2111', '2717', 'd']], dtype='<U21')

# %% [markdown]
# [pandas.date_range](https://pandas.pydata.org/docs/reference/api/pandas.date_range.html)

# %%
fecha = pd.date_range("20230915", periods=20)

# %%
df = pd.DataFrame(values, index=fecha, columns=list("VWXYZ"))
df
# Out:
#                V     W     X     Y  Z
# 2023-09-15  2138   701  2557  2560  a
# 2023-09-16   185  1807  2973  2346  b
# 2023-09-17   685   417   389   148  c
# 2023-09-18  1328   187  2552  1707  d
# 2023-09-19  2717  2426   418   836  a
# 2023-09-20  1771  2006  2394  1888  b
# 2023-09-21  2092   695   469   991  c
# 2023-09-22  2755   122  1447  1644  d
# 2023-09-23  2304  2451  1875  1082  a
# 2023-09-24  1490  1231  2758   336  b
# 2023-09-25  2855  1473  2834  2369  c
# 2023-09-26   426  2874  1081  2269  d
# 2023-09-27  2893  1889  2140   315  a
# 2023-09-28  1265  1680   130  2103  b
# 2023-09-29  2569  2232   503  2323  c
# 2023-09-30  1638   855  1835  2192  d
# 2023-10-01  2370  2131   614  1391  a
# 2023-10-02  2636  2756  1602  1417  b
# 2023-10-03  2205  2120   987   120  c
# 2023-10-04  1871  2981  2111  2717  d

# %% [markdown]
# ## acceder a los elementos por índice (DateTime)
#
# Al igual que con las series, se pueden seleccionar elementos por índice o valor/valores

# %%
df['2023-09-26':'2023-09-30']
# Out:
#                V     W     X     Y  Z
# 2023-09-26   426  2874  1081  2269  d
# 2023-09-27  2893  1889  2140   315  a
# 2023-09-28  1265  1680   130  2103  b
# 2023-09-29  2569  2232   503  2323  c
# 2023-09-30  1638   855  1835  2192  d

# %%
#df['2023-09-26']  #error

# %%
df.loc['2023-09-26']
# Out:
# V     426
# W    2874
# X    1081
# Y    2269
# Z       d
# Name: 2023-09-26 00:00:00, dtype: object

# %%
df.loc['2023-09-26':'2023-09-30']
# Out:
#                V     W     X     Y  Z
# 2023-09-26   426  2874  1081  2269  d
# 2023-09-27  2893  1889  2140   315  a
# 2023-09-28  1265  1680   130  2103  b
# 2023-09-29  2569  2232   503  2323  c
# 2023-09-30  1638   855  1835  2192  d

# %%
df.iloc[3]
# Out:
# V    1328
# W     187
# X    2552
# Y    1707
# Z       d
# Name: 2023-09-18 00:00:00, dtype: object

# %%
df['W']
# Out:
# 2023-09-15     701
# 2023-09-16    1807
# 2023-09-17     417
# 2023-09-18     187
# 2023-09-19    2426
# 2023-09-20    2006
# 2023-09-21     695
# 2023-09-22     122
# 2023-09-23    2451
# 2023-09-24    1231
# 2023-09-25    1473
# 2023-09-26    2874
# 2023-09-27    1889
# 2023-09-28    1680
# 2023-09-29    2232
# 2023-09-30     855
# 2023-10-01    2131
# 2023-10-02    2756
# 2023-10-03    2120
# 2023-10-04    2981
# Freq: D, Name: W, dtype: object

# %%
df[['W','Z']]
# Out:
#                W  Z
# 2023-09-15   701  a
# 2023-09-16  1807  b
# 2023-09-17   417  c
# 2023-09-18   187  d
# 2023-09-19  2426  a
# 2023-09-20  2006  b
# 2023-09-21   695  c
# 2023-09-22   122  d
# 2023-09-23  2451  a
# 2023-09-24  1231  b
# 2023-09-25  1473  c
# 2023-09-26  2874  d
# 2023-09-27  1889  a
# 2023-09-28  1680  b
# 2023-09-29  2232  c
# 2023-09-30   855  d
# 2023-10-01  2131  a
# 2023-10-02  2756  b
# 2023-10-03  2120  c
# 2023-10-04  2981  d

# %%
df.loc['2023-09-26','Y'] #seleccionar por índice y columna
# Out:
# '2269'

# %%
df.loc['2023-09-26':'2023-09-30',['W','Y']]
# Out:
#                W     Y
# 2023-09-26  2874  2269
# 2023-09-27  1889   315
# 2023-09-28  1680  2103
# 2023-09-29  2232  2323
# 2023-09-30   855  2192

# %%
df.loc[['2023-09-26','2023-09-30'], ['W','Z']]
# Out:
#                W  Z
# 2023-09-26  2874  d
# 2023-09-30   855  d

# %%
df[['W','Z']].iloc[0:5]
# Out:
#                W  Z
# 2023-09-15   701  a
# 2023-09-16  1807  b
# 2023-09-17   417  c
# 2023-09-18   187  d
# 2023-09-19  2426  a

# %%
df[['W','Z']].loc[['2023-09-26','2023-09-30']]
# Out:
#                W  Z
# 2023-09-26  2874  d
# 2023-09-30   855  d

# %% [markdown]
# ## Exploración de los datos

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# V    object
# W    object
# X    object
# Y    object
# Z    object
# dtype: object

# %%
df.columns
# Out:
# Index(['V', 'W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2023-09-15', '2023-09-16', '2023-09-17', '2023-09-18',
#                '2023-09-19', '2023-09-20', '2023-09-21', '2023-09-22',
#                '2023-09-23', '2023-09-24', '2023-09-25', '2023-09-26',
#                '2023-09-27', '2023-09-28', '2023-09-29', '2023-09-30',
#                '2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.head(3) #primeras filas
# Out:
#                V     W     X     Y  Z
# 2023-09-15  2138   701  2557  2560  a
# 2023-09-16   185  1807  2973  2346  b
# 2023-09-17   685   417   389   148  c

# %%
df.tail(3) #últimas filas
# Out:
#                V     W     X     Y  Z
# 2023-10-02  2636  2756  1602  1417  b
# 2023-10-03  2205  2120   987   120  c
# 2023-10-04  1871  2981  2111  2717  d

# %%
df.sample(3) # seleccion aleatoria
# Out:
#                V     W     X     Y  Z
# 2023-09-19  2717  2426   418   836  a
# 2023-10-02  2636  2756  1602  1417  b
# 2023-09-27  2893  1889  2140   315  a

# %%
df.describe()
# Out:
#            V    W     X     Y   Z
# count     20   20    20    20  20
# unique    20   20    20    20   4
# top     2138  701  2557  2560   a
# freq       1    1     1     1   5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2023-09-15 to 2023-10-04
# Freq: D
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V       20 non-null     object
#  1   W       20 non-null     object
#  2   X       20 non-null     object
#  3   Y       20 non-null     object
#  4   Z       20 non-null     object
# dtypes: object(5)
# memory usage: 1.5+ KB

# %% [markdown]
# ## Añadir y eliminar filas/columnas

# %%
df['new_col'] = 2*df['W'] + df['Y']
df.head()
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  2138   701  2557  2560  a    7017012560
# 2023-09-16   185  1807  2973  2346  b  180718072346
# 2023-09-17   685   417   389   148  c     417417148
# 2023-09-18  1328   187  2552  1707  d    1871871707
# 2023-09-19  2717  2426   418   836  a   24262426836

# %%
#df.append(df) # Concatenate dataframes
pd.concat([df, df])
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  2138   701  2557  2560  a    7017012560
# 2023-09-16   185  1807  2973  2346  b  180718072346
# 2023-09-17   685   417   389   148  c     417417148
# 2023-09-18  1328   187  2552  1707  d    1871871707
# 2023-09-19  2717  2426   418   836  a   24262426836
# 2023-09-20  1771  2006  2394  1888  b  200620061888
# 2023-09-21  2092   695   469   991  c     695695991
# 2023-09-22  2755   122  1447  1644  d    1221221644
# 2023-09-23  2304  2451  1875  1082  a  245124511082
# 2023-09-24  1490  1231  2758   336  b   12311231336
# 2023-09-25  2855  1473  2834  2369  c  147314732369
# 2023-09-26   426  2874  1081  2269  d  287428742269
# 2023-09-27  2893  1889  2140   315  a   18891889315
# 2023-09-28  1265  1680   130  2103  b  168016802103
# 2023-09-29  2569  2232   503  2323  c  223222322323
# 2023-09-30  1638   855  1835  2192  d    8558552192
# 2023-10-01  2370  2131   614  1391  a  213121311391
# 2023-10-02  2636  2756  1602  1417  b  275627561417
# 2023-10-03  2205  2120   987   120  c   21202120120
# 2023-10-04  1871  2981  2111  2717  d  298129812717
# 2023-09-15  2138   701  2557  2560  a    7017012560
# 2023-09-16   185  1807  2973  2346  b  180718072346
# 2023-09-17   685   417   389   148  c     417417148
# 2023-09-18  1328   187  2552  1707  d    1871871707
# 2023-09-19  2717  2426   418   836  a   24262426836
# 2023-09-20  1771  2006  2394  1888  b  200620061888
# 2023-09-21  2092   695   469   991  c     695695991
# 2023-09-22  2755   122  1447  1644  d    1221221644
# 2023-09-23  2304  2451  1875  1082  a  245124511082
# 2023-09-24  1490  1231  2758   336  b   12311231336
# 2023-09-25  2855  1473  2834  2369  c  147314732369
# 2023-09-26   426  2874  1081  2269  d  287428742269
# 2023-09-27  2893  1889  2140   315  a   18891889315
# 2023-09-28  1265  1680   130  2103  b  168016802103
# 2023-09-29  2569  2232   503  2323  c  223222322323
# 2023-09-30  1638   855  1835  2192  d    8558552192
# 2023-10-01  2370  2131   614  1391  a  213121311391
# 2023-10-02  2636  2756  1602  1417  b  275627561417
# 2023-10-03  2205  2120   987   120  c   21202120120
# 2023-10-04  1871  2981  2111  2717  d  298129812717

# %%
pd.concat([df, df], ignore_index = True) # Ignore index
# Out:
#        V     W     X     Y  Z       new_col
# 0   2138   701  2557  2560  a    7017012560
# 1    185  1807  2973  2346  b  180718072346
# 2    685   417   389   148  c     417417148
# 3   1328   187  2552  1707  d    1871871707
# 4   2717  2426   418   836  a   24262426836
# 5   1771  2006  2394  1888  b  200620061888
# 6   2092   695   469   991  c     695695991
# 7   2755   122  1447  1644  d    1221221644
# 8   2304  2451  1875  1082  a  245124511082
# 9   1490  1231  2758   336  b   12311231336
# 10  2855  1473  2834  2369  c  147314732369
# 11   426  2874  1081  2269  d  287428742269
# 12  2893  1889  2140   315  a   18891889315
# 13  1265  1680   130  2103  b  168016802103
# 14  2569  2232   503  2323  c  223222322323
# 15  1638   855  1835  2192  d    8558552192
# 16  2370  2131   614  1391  a  213121311391
# 17  2636  2756  1602  1417  b  275627561417
# 18  2205  2120   987   120  c   21202120120
# 19  1871  2981  2111  2717  d  298129812717
# 20  2138   701  2557  2560  a    7017012560
# 21   185  1807  2973  2346  b  180718072346
# 22   685   417   389   148  c     417417148
# 23  1328   187  2552  1707  d    1871871707
# 24  2717  2426   418   836  a   24262426836
# 25  1771  2006  2394  1888  b  200620061888
# 26  2092   695   469   991  c     695695991
# 27  2755   122  1447  1644  d    1221221644
# 28  2304  2451  1875  1082  a  245124511082
# 29  1490  1231  2758   336  b   12311231336
# 30  2855  1473  2834  2369  c  147314732369
# 31   426  2874  1081  2269  d  287428742269
# 32  2893  1889  2140   315  a   18891889315
# 33  1265  1680   130  2103  b  168016802103
# 34  2569  2232   503  2323  c  223222322323
# 35  1638   855  1835  2192  d    8558552192
# 36  2370  2131   614  1391  a  213121311391
# 37  2636  2756  1602  1417  b  275627561417
# 38  2205  2120   987   120  c   21202120120
# 39  1871  2981  2111  2717  d  298129812717

# %%
df
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  2138   701  2557  2560  a    7017012560
# 2023-09-16   185  1807  2973  2346  b  180718072346
# 2023-09-17   685   417   389   148  c     417417148
# 2023-09-18  1328   187  2552  1707  d    1871871707
# 2023-09-19  2717  2426   418   836  a   24262426836
# 2023-09-20  1771  2006  2394  1888  b  200620061888
# 2023-09-21  2092   695   469   991  c     695695991
# 2023-09-22  2755   122  1447  1644  d    1221221644
# 2023-09-23  2304  2451  1875  1082  a  245124511082
# 2023-09-24  1490  1231  2758   336  b   12311231336
# 2023-09-25  2855  1473  2834  2369  c  147314732369
# 2023-09-26   426  2874  1081  2269  d  287428742269
# 2023-09-27  2893  1889  2140   315  a   18891889315
# 2023-09-28  1265  1680   130  2103  b  168016802103
# 2023-09-29  2569  2232   503  2323  c  223222322323
# 2023-09-30  1638   855  1835  2192  d    8558552192
# 2023-10-01  2370  2131   614  1391  a  213121311391
# 2023-10-02  2636  2756  1602  1417  b  275627561417
# 2023-10-03  2205  2120   987   120  c   21202120120
# 2023-10-04  1871  2981  2111  2717  d  298129812717

# %%
df.drop('2023-09-26') #default: axis = 0
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  2138   701  2557  2560  a    7017012560
# 2023-09-16   185  1807  2973  2346  b  180718072346
# 2023-09-17   685   417   389   148  c     417417148
# 2023-09-18  1328   187  2552  1707  d    1871871707
# 2023-09-19  2717  2426   418   836  a   24262426836
# 2023-09-20  1771  2006  2394  1888  b  200620061888
# 2023-09-21  2092   695   469   991  c     695695991
# 2023-09-22  2755   122  1447  1644  d    1221221644
# 2023-09-23  2304  2451  1875  1082  a  245124511082
# 2023-09-24  1490  1231  2758   336  b   12311231336
# 2023-09-25  2855  1473  2834  2369  c  147314732369
# 2023-09-27  2893  1889  2140   315  a   18891889315
# 2023-09-28  1265  1680   130  2103  b  168016802103
# 2023-09-29  2569  2232   503  2323  c  223222322323
# 2023-09-30  1638   855  1835  2192  d    8558552192
# 2023-10-01  2370  2131   614  1391  a  213121311391
# 2023-10-02  2636  2756  1602  1417  b  275627561417
# 2023-10-03  2205  2120   987   120  c   21202120120
# 2023-10-04  1871  2981  2111  2717  d  298129812717

# %%
df.drop('2023-09-15', axis=0)
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-16   185  1807  2973  2346  b  180718072346
# 2023-09-17   685   417   389   148  c     417417148
# 2023-09-18  1328   187  2552  1707  d    1871871707
# 2023-09-19  2717  2426   418   836  a   24262426836
# 2023-09-20  1771  2006  2394  1888  b  200620061888
# 2023-09-21  2092   695   469   991  c     695695991
# 2023-09-22  2755   122  1447  1644  d    1221221644
# 2023-09-23  2304  2451  1875  1082  a  245124511082
# 2023-09-24  1490  1231  2758   336  b   12311231336
# 2023-09-25  2855  1473  2834  2369  c  147314732369
# 2023-09-26   426  2874  1081  2269  d  287428742269
# 2023-09-27  2893  1889  2140   315  a   18891889315
# 2023-09-28  1265  1680   130  2103  b  168016802103
# 2023-09-29  2569  2232   503  2323  c  223222322323
# 2023-09-30  1638   855  1835  2192  d    8558552192
# 2023-10-01  2370  2131   614  1391  a  213121311391
# 2023-10-02  2636  2756  1602  1417  b  275627561417
# 2023-10-03  2205  2120   987   120  c   21202120120
# 2023-10-04  1871  2981  2111  2717  d  298129812717

# %%
df.head()
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  2138   701  2557  2560  a    7017012560
# 2023-09-16   185  1807  2973  2346  b  180718072346
# 2023-09-17   685   417   389   148  c     417417148
# 2023-09-18  1328   187  2552  1707  d    1871871707
# 2023-09-19  2717  2426   418   836  a   24262426836

# %%
df.drop('new_col',axis=1) # para eliminar columnas axis = 1
# Out:
#                V     W     X     Y  Z
# 2023-09-15  2138   701  2557  2560  a
# 2023-09-16   185  1807  2973  2346  b
# 2023-09-17   685   417   389   148  c
# 2023-09-18  1328   187  2552  1707  d
# 2023-09-19  2717  2426   418   836  a
# 2023-09-20  1771  2006  2394  1888  b
# 2023-09-21  2092   695   469   991  c
# 2023-09-22  2755   122  1447  1644  d
# 2023-09-23  2304  2451  1875  1082  a
# 2023-09-24  1490  1231  2758   336  b
# 2023-09-25  2855  1473  2834  2369  c
# 2023-09-26   426  2874  1081  2269  d
# 2023-09-27  2893  1889  2140   315  a
# 2023-09-28  1265  1680   130  2103  b
# 2023-09-29  2569  2232   503  2323  c
# 2023-09-30  1638   855  1835  2192  d
# 2023-10-01  2370  2131   614  1391  a
# 2023-10-02  2636  2756  1602  1417  b
# 2023-10-03  2205  2120   987   120  c
# 2023-10-04  1871  2981  2111  2717  d

# %%
df.head()
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  2138   701  2557  2560  a    7017012560
# 2023-09-16   185  1807  2973  2346  b  180718072346
# 2023-09-17   685   417   389   148  c     417417148
# 2023-09-18  1328   187  2552  1707  d    1871871707
# 2023-09-19  2717  2426   418   836  a   24262426836

# %%
df.drop('new_col',axis=1, inplace=True) # para guardar el cambio

# %%
df.head()
# Out:
#                V     W     X     Y  Z
# 2023-09-15  2138   701  2557  2560  a
# 2023-09-16   185  1807  2973  2346  b
# 2023-09-17   685   417   389   148  c
# 2023-09-18  1328   187  2552  1707  d
# 2023-09-19  2717  2426   418   836  a

# %%
df.drop(columns=['V', 'Y'])
# Out:
#                W     X  Z
# 2023-09-15   701  2557  a
# 2023-09-16  1807  2973  b
# 2023-09-17   417   389  c
# 2023-09-18   187  2552  d
# 2023-09-19  2426   418  a
# 2023-09-20  2006  2394  b
# 2023-09-21   695   469  c
# 2023-09-22   122  1447  d
# 2023-09-23  2451  1875  a
# 2023-09-24  1231  2758  b
# 2023-09-25  1473  2834  c
# 2023-09-26  2874  1081  d
# 2023-09-27  1889  2140  a
# 2023-09-28  1680   130  b
# 2023-09-29  2232   503  c
# 2023-09-30   855  1835  d
# 2023-10-01  2131   614  a
# 2023-10-02  2756  1602  b
# 2023-10-03  2120   987  c
# 2023-10-04  2981  2111  d

# %% [markdown]
# ## Operaciones y manipulación

# %%
df.sort_index(ascending=False)
# Out:
#                V     W     X     Y  Z
# 2023-10-04  1871  2981  2111  2717  d
# 2023-10-03  2205  2120   987   120  c
# 2023-10-02  2636  2756  1602  1417  b
# 2023-10-01  2370  2131   614  1391  a
# 2023-09-30  1638   855  1835  2192  d
# 2023-09-29  2569  2232   503  2323  c
# 2023-09-28  1265  1680   130  2103  b
# 2023-09-27  2893  1889  2140   315  a
# 2023-09-26   426  2874  1081  2269  d
# 2023-09-25  2855  1473  2834  2369  c
# 2023-09-24  1490  1231  2758   336  b
# 2023-09-23  2304  2451  1875  1082  a
# 2023-09-22  2755   122  1447  1644  d
# 2023-09-21  2092   695   469   991  c
# 2023-09-20  1771  2006  2394  1888  b
# 2023-09-19  2717  2426   418   836  a
# 2023-09-18  1328   187  2552  1707  d
# 2023-09-17   685   417   389   148  c
# 2023-09-16   185  1807  2973  2346  b
# 2023-09-15  2138   701  2557  2560  a

# %%
df.sort_values(by=['V'], ascending = True)  #no funciona
# Out:
#                V     W     X     Y  Z
# 2023-09-28  1265  1680   130  2103  b
# 2023-09-18  1328   187  2552  1707  d
# 2023-09-24  1490  1231  2758   336  b
# 2023-09-30  1638   855  1835  2192  d
# 2023-09-20  1771  2006  2394  1888  b
# 2023-09-16   185  1807  2973  2346  b
# 2023-10-04  1871  2981  2111  2717  d
# 2023-09-21  2092   695   469   991  c
# 2023-09-15  2138   701  2557  2560  a
# 2023-10-03  2205  2120   987   120  c
# 2023-09-23  2304  2451  1875  1082  a
# 2023-10-01  2370  2131   614  1391  a
# 2023-09-29  2569  2232   503  2323  c
# 2023-10-02  2636  2756  1602  1417  b
# 2023-09-19  2717  2426   418   836  a
# 2023-09-22  2755   122  1447  1644  d
# 2023-09-25  2855  1473  2834  2369  c
# 2023-09-27  2893  1889  2140   315  a
# 2023-09-26   426  2874  1081  2269  d
# 2023-09-17   685   417   389   148  c

# %%
cambiar_tipo = {
    'V': 'int64',
    'W': 'int64' }

df = df.astype(cambiar_tipo)

# %%
df.dtypes
# Out:
# V     int64
# W     int64
# X    object
# Y    object
# Z    object
# dtype: object

# %%
df.sort_values(by=['V'], ascending = False)
# Out:
#                V     W     X     Y  Z
# 2023-09-27  2893  1889  2140   315  a
# 2023-09-25  2855  1473  2834  2369  c
# 2023-09-22  2755   122  1447  1644  d
# 2023-09-19  2717  2426   418   836  a
# 2023-10-02  2636  2756  1602  1417  b
# 2023-09-29  2569  2232   503  2323  c
# 2023-10-01  2370  2131   614  1391  a
# 2023-09-23  2304  2451  1875  1082  a
# 2023-10-03  2205  2120   987   120  c
# 2023-09-15  2138   701  2557  2560  a
# 2023-09-21  2092   695   469   991  c
# 2023-10-04  1871  2981  2111  2717  d
# 2023-09-20  1771  2006  2394  1888  b
# 2023-09-30  1638   855  1835  2192  d
# 2023-09-24  1490  1231  2758   336  b
# 2023-09-18  1328   187  2552  1707  d
# 2023-09-28  1265  1680   130  2103  b
# 2023-09-17   685   417   389   148  c
# 2023-09-26   426  2874  1081  2269  d
# 2023-09-16   185  1807  2973  2346  b

# %%
df.reset_index(inplace = True)
df
# Out:
#         index     V     W     X     Y  Z
# 0  2023-09-15  2138   701  2557  2560  a
# 1  2023-09-16   185  1807  2973  2346  b
# 2  2023-09-17   685   417   389   148  c
# 3  2023-09-18  1328   187  2552  1707  d
# 4  2023-09-19  2717  2426   418   836  a
# 5  2023-09-20  1771  2006  2394  1888  b
# 6  2023-09-21  2092   695   469   991  c
# 7  2023-09-22  2755   122  1447  1644  d
# 8  2023-09-23  2304  2451  1875  1082  a
# 9  2023-09-24  1490  1231  2758   336  b
# 10 2023-09-25  2855  1473  2834  2369  c
# 11 2023-09-26   426  2874  1081  2269  d
# 12 2023-09-27  2893  1889  2140   315  a
# 13 2023-09-28  1265  1680   130  2103  b
# 14 2023-09-29  2569  2232   503  2323  c
# 15 2023-09-30  1638   855  1835  2192  d
# 16 2023-10-01  2370  2131   614  1391  a
# 17 2023-10-02  2636  2756  1602  1417  b
# 18 2023-10-03  2205  2120   987   120  c
# 19 2023-10-04  1871  2981  2111  2717  d

# %%
df.set_index('Z', inplace = True)

# %%
df.dtypes
# Out:
# index    datetime64[ns]
# V                 int64
# W                 int64
# X                object
# Y                object
# dtype: object

# %% [markdown]
# ### Filtrando elementos

# %%
df[['V', 'W']] > 1000
# Out:
#        V      W
# Z
# a   True  False
# b  False   True
# c  False  False
# d   True  False
# a   True   True
# b   True   True
# c   True  False
# d   True  False
# a   True   True
# b   True   True
# c   True   True
# d  False   True
# a   True   True
# b   True   True
# c   True   True
# d   True  False
# a   True   True
# b   True   True
# c   True   True
# d   True   True

# %%
df[df['W'] > 1000]
# Out:
#        index     V     W     X     Y
# Z
# b 2023-09-16   185  1807  2973  2346
# a 2023-09-19  2717  2426   418   836
# b 2023-09-20  1771  2006  2394  1888
# a 2023-09-23  2304  2451  1875  1082
# b 2023-09-24  1490  1231  2758   336
# c 2023-09-25  2855  1473  2834  2369
# d 2023-09-26   426  2874  1081  2269
# a 2023-09-27  2893  1889  2140   315
# b 2023-09-28  1265  1680   130  2103
# c 2023-09-29  2569  2232   503  2323
# a 2023-10-01  2370  2131   614  1391
# b 2023-10-02  2636  2756  1602  1417
# c 2023-10-03  2205  2120   987   120
# d 2023-10-04  1871  2981  2111  2717

# %%
df[df['W'] > 1000][['X', 'V']]
# Out:
#       X     V
# Z
# b  2973   185
# a   418  2717
# b  2394  1771
# a  1875  2304
# b  2758  1490
# c  2834  2855
# d  1081   426
# a  2140  2893
# b   130  1265
# c   503  2569
# a   614  2370
# b  1602  2636
# c   987  2205
# d  2111  1871

# %%
df[df['W'] > 0][['Y','X']]
# Out:
#       Y     X
# Z
# a  2560  2557
# b  2346  2973
# c   148   389
# d  1707  2552
# a   836   418
# b  1888  2394
# c   991   469
# d  1644  1447
# a  1082  1875
# b   336  2758
# c  2369  2834
# d  2269  1081
# a   315  2140
# b  2103   130
# c  2323   503
# d  2192  1835
# a  1391   614
# b  1417  1602
# c   120   987
# d  2717  2111

# %%
df[(df['W'] <= 1500) & (df['V'] > 1000)]
# Out:
#        index     V     W     X     Y
# Z
# a 2023-09-15  2138   701  2557  2560
# d 2023-09-18  1328   187  2552  1707
# c 2023-09-21  2092   695   469   991
# d 2023-09-22  2755   122  1447  1644
# b 2023-09-24  1490  1231  2758   336
# c 2023-09-25  2855  1473  2834  2369
# d 2023-09-30  1638   855  1835  2192

# %%
df2 = df[(df['W'] <= 1500) & (df['V'] > 1000)]

df2
# Out:
#        index     V     W     X     Y
# Z
# a 2023-09-15  2138   701  2557  2560
# d 2023-09-18  1328   187  2552  1707
# c 2023-09-21  2092   695   469   991
# d 2023-09-22  2755   122  1447  1644
# b 2023-09-24  1490  1231  2758   336
# c 2023-09-25  2855  1473  2834  2369
# d 2023-09-30  1638   855  1835  2192

# %%
df2.loc['d']
# Out:
#        index     V    W     X     Y
# Z
# d 2023-09-18  1328  187  2552  1707
# d 2023-09-22  2755  122  1447  1644
# d 2023-09-30  1638  855  1835  2192

# %%
# Renombrar columnas:

df2 = df2.rename(columns={'index':'Fecha', 'V':'numero_eventos', 'Y':'masa'})
df2.head()
# Out:
#        Fecha  numero_eventos     W     X  masa
# Z
# a 2023-09-15            2138   701  2557  2560
# d 2023-09-18            1328   187  2552  1707
# c 2023-09-21            2092   695   469   991
# d 2023-09-22            2755   122  1447  1644
# b 2023-09-24            1490  1231  2758   336

# %% [markdown]
# ## Lectura/escritura de archivos csv, JSON
#
# [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html#pandas.read_csv)
#
# [to_csv](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)

# %%
df2.to_csv('prueba.csv', sep=',')

# %%
df2.to_csv('prueba.csv', sep=',', index=False)

# %%
df = pd.read_csv('prueba.csv')

# %%
df.head()
# Out:
#         Fecha  numero_eventos     W     X  masa
# 0  2023-09-15            2138   701  2557  2560
# 1  2023-09-18            1328   187  2552  1707
# 2  2023-09-21            2092   695   469   991
# 3  2023-09-22            2755   122  1447  1644
# 4  2023-09-24            1490  1231  2758   336

# %%
df2.to_csv('prueba.csv', sep=',')
df = pd.read_csv('prueba.csv')
df.head()
# Out:
#    Z       Fecha  numero_eventos     W     X  masa
# 0  a  2023-09-15            2138   701  2557  2560
# 1  d  2023-09-18            1328   187  2552  1707
# 2  c  2023-09-21            2092   695   469   991
# 3  d  2023-09-22            2755   122  1447  1644
# 4  b  2023-09-24            1490  1231  2758   336

# %%
df = pd.read_csv('prueba.csv', index_col = 'Z')
df.head()
# Out:
#         Fecha  numero_eventos     W     X  masa
# Z
# a  2023-09-15            2138   701  2557  2560
# d  2023-09-18            1328   187  2552  1707
# c  2023-09-21            2092   695   469   991
# d  2023-09-22            2755   122  1447  1644
# b  2023-09-24            1490  1231  2758   336

# %% [markdown]
# ## Ejercicio
#
# Descargar el archivo GCB2022v27_MtCO2_flat.csv de [kaggle](https://www.kaggle.com/datasets/thedevastator/global-fossil-co2-emissions-by-country-2002-2022)
#
# * Explorar el dataset
# * Obtener datos estadísticos de México
# * Comparar los valores de Mexico con los valores globales.
# * Graficar

# %% [markdown]
# ### JSON
# [kaggle](https://www.kaggle.com/datasets/thedevastator/global-fossil-co2-emissions-by-country-2002-2022)

# %%
json_file = pd.read_json('../../data/kaggle_CO2emission/GCB2022v27_MtCO2_flat_metadata.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_751/909543699.py in <module>
# ----> 1 json_file = pd.read_json('../../data/kaggle_CO2emission/GCB2022v27_MtCO2_flat_metadata.json')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     610
#     611     with json_reader:
# --> 612         return json_reader.read()
#     613
#     614
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in read(self)
#     744                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     745         else:
# --> 746             obj = self._get_object_parser(self.data)
#     747         self.close()
#     748         return obj
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     766         obj = None
#     767         if typ == "frame":
# --> 768             obj = FrameParser(json, **kwargs).parse()
#     769
#     770         if typ == "series" or obj is None:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in parse(self)
#     878             self._parse_numpy()
#     879         else:
# --> 880             self._parse_no_numpy()
#     881
#     882         if self.obj is None:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1131         if orient == "columns":
#    1132             self.obj = DataFrame(
# -> 1133                 loads(json, precise_float=self.precise_float), dtype=None
#    1134             )
#    1135         elif orient == "split":
#
# ValueError: Expected object or value

# %%
dataCO2 = pd.read_csv('GCB2022v27_MtCO2_flat.csv')

# %%
dataCO2
# Out:
#            Country ISO 3166-1 alpha-3  Year         Total          Coal  \
# 0      Afghanistan                AFG  1750      0.000000           NaN
# 1      Afghanistan                AFG  1751      0.000000           NaN
# 2      Afghanistan                AFG  1752      0.000000           NaN
# 3      Afghanistan                AFG  1753      0.000000           NaN
# 4      Afghanistan                AFG  1754      0.000000           NaN
# ...            ...                ...   ...           ...           ...
# 63099       Global                WLD  2017  36096.739276  14506.973805
# 63100       Global                WLD  2018  36826.506600  14746.830688
# 63101       Global                WLD  2019  37082.558969  14725.978025
# 63102       Global                WLD  2020  35264.085734  14174.564010
# 63103       Global                WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# 0               NaN          NaN          NaN         NaN         NaN
# 1               NaN          NaN          NaN         NaN         NaN
# 2               NaN          NaN          NaN         NaN         NaN
# 3               NaN          NaN          NaN         NaN         NaN
# 4               NaN          NaN          NaN         NaN         NaN
# ...             ...          ...          ...         ...         ...
# 63099  12242.627935  7144.928128  1507.923185  391.992176  302.294047
# 63100  12266.016285  7529.846784  1569.218392  412.115746  302.478706
# 63101  12345.653374  7647.528220  1617.506786  439.253991  306.638573
# 63102  11191.808551  7556.290283  1637.537532  407.583673  296.301685
# 63103  11837.159116  7921.829472  1672.592372  416.525563  296.145746
#
#        Per Capita
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 63099    4.749682
# 63100    4.792753
# 63101    4.775633
# 63102    4.497423
# 63103    4.693699
#
# [63104 rows x 11 columns]

# %%
data = dataCO2["Country"]=="Mexico"

# %%
dataMEX = dataCO2[data]
dataMEX
# Out:
#       Country ISO 3166-1 alpha-3  Year       Total       Coal         Oil  \
# 36176  Mexico                MEX  1750    0.000000        NaN         NaN
# 36177  Mexico                MEX  1751    0.000000        NaN         NaN
# 36178  Mexico                MEX  1752    0.000000        NaN         NaN
# 36179  Mexico                MEX  1753    0.000000        NaN         NaN
# 36180  Mexico                MEX  1754    0.000000        NaN         NaN
# ...       ...                ...   ...         ...        ...         ...
# 36443  Mexico                MEX  2017  465.620953  48.529680  245.839744
# 36444  Mexico                MEX  2018  475.268909  47.313232  233.825488
# 36445  Mexico                MEX  2019  472.191499  45.268010  241.897149
# 36446  Mexico                MEX  2020  391.706208  20.011074  190.678139
# 36447  Mexico                MEX  2021  407.205037  19.360577  195.715517
#
#               Gas     Cement    Flaring  Other  Per Capita
# 36176         NaN        NaN        NaN    NaN         NaN
# 36177         NaN        NaN        NaN    NaN         NaN
# 36178         NaN        NaN        NaN    NaN         NaN
# 36179         NaN        NaN        NaN    NaN         NaN
# 36180         NaN        NaN        NaN    NaN         NaN
# ...           ...        ...        ...    ...         ...
# 36443  143.251408  20.876858   7.123264    NaN    3.790490
# 36444  165.905920  20.863843   7.360426    NaN    3.832385
# 36445  157.098863  19.497632   8.429845    NaN    3.774956
# 36446  149.524596  20.650326  10.842073    NaN    3.108821
# 36447  157.552711  22.339198  12.237033    NaN    3.213801
#
# [272 rows x 11 columns]

# %%
dataMEX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272 entries, 36176 to 36447
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             272 non-null    object
#  1   ISO 3166-1 alpha-3  272 non-null    object
#  2   Year                272 non-null    int64
#  3   Total               272 non-null    float64
#  4   Coal                131 non-null    float64
#  5   Oil                 131 non-null    float64
#  6   Gas                 131 non-null    float64
#  7   Cement              94 non-null     float64
#  8   Flaring             131 non-null    float64
#  9   Other               0 non-null      float64
#  10  Per Capita          72 non-null     float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 25.5+ KB

# %%
columns = dataMEX.columns
columns
# Out:
# Index(['Country', 'ISO 3166-1 alpha-3', 'Year', 'Total', 'Coal', 'Oil', 'Gas',
#        'Cement', 'Flaring', 'Other', 'Per Capita'],
#       dtype='object')

# %%
year = dataMEX["Year"].values

# %%
dataMEX[columns[3:]]
# Out:
#             Total       Coal         Oil         Gas     Cement    Flaring  \
# 36176    0.000000        NaN         NaN         NaN        NaN        NaN
# 36177    0.000000        NaN         NaN         NaN        NaN        NaN
# 36178    0.000000        NaN         NaN         NaN        NaN        NaN
# 36179    0.000000        NaN         NaN         NaN        NaN        NaN
# 36180    0.000000        NaN         NaN         NaN        NaN        NaN
# ...           ...        ...         ...         ...        ...        ...
# 36443  465.620953  48.529680  245.839744  143.251408  20.876858   7.123264
# 36444  475.268909  47.313232  233.825488  165.905920  20.863843   7.360426
# 36445  472.191499  45.268010  241.897149  157.098863  19.497632   8.429845
# 36446  391.706208  20.011074  190.678139  149.524596  20.650326  10.842073
# 36447  407.205037  19.360577  195.715517  157.552711  22.339198  12.237033
#
#        Other  Per Capita
# 36176    NaN         NaN
# 36177    NaN         NaN
# 36178    NaN         NaN
# 36179    NaN         NaN
# 36180    NaN         NaN
# ...      ...         ...
# 36443    NaN    3.790490
# 36444    NaN    3.832385
# 36445    NaN    3.774956
# 36446    NaN    3.108821
# 36447    NaN    3.213801
#
# [272 rows x 8 columns]

# %%
dataMEX_year = dataMEX[columns[3:]].set_index(year)
dataMEX_year
# Out:
#            Total       Coal         Oil         Gas     Cement    Flaring  \
# 1750    0.000000        NaN         NaN         NaN        NaN        NaN
# 1751    0.000000        NaN         NaN         NaN        NaN        NaN
# 1752    0.000000        NaN         NaN         NaN        NaN        NaN
# 1753    0.000000        NaN         NaN         NaN        NaN        NaN
# 1754    0.000000        NaN         NaN         NaN        NaN        NaN
# ...          ...        ...         ...         ...        ...        ...
# 2017  465.620953  48.529680  245.839744  143.251408  20.876858   7.123264
# 2018  475.268909  47.313232  233.825488  165.905920  20.863843   7.360426
# 2019  472.191499  45.268010  241.897149  157.098863  19.497632   8.429845
# 2020  391.706208  20.011074  190.678139  149.524596  20.650326  10.842073
# 2021  407.205037  19.360577  195.715517  157.552711  22.339198  12.237033
#
#       Other  Per Capita
# 1750    NaN         NaN
# 1751    NaN         NaN
# 1752    NaN         NaN
# 1753    NaN         NaN
# 1754    NaN         NaN
# ...     ...         ...
# 2017    NaN    3.790490
# 2018    NaN    3.832385
# 2019    NaN    3.774956
# 2020    NaN    3.108821
# 2021    NaN    3.213801
#
# [272 rows x 8 columns]

# %%
dataMEX_year[dataMEX_year["Total"] != 0.0]
# Out:
#            Total       Coal         Oil         Gas     Cement    Flaring  \
# 1891    0.520288   0.520288    0.000000    0.000000        NaN   0.000000
# 1892    0.578912   0.578912    0.000000    0.000000        NaN   0.000000
# 1893    0.531280   0.531280    0.000000    0.000000        NaN   0.000000
# 1894    0.538608   0.538608    0.000000    0.000000        NaN   0.000000
# 1895    0.494640   0.494640    0.000000    0.000000        NaN   0.000000
# ...          ...        ...         ...         ...        ...        ...
# 2017  465.620953  48.529680  245.839744  143.251408  20.876858   7.123264
# 2018  475.268909  47.313232  233.825488  165.905920  20.863843   7.360426
# 2019  472.191499  45.268010  241.897149  157.098863  19.497632   8.429845
# 2020  391.706208  20.011074  190.678139  149.524596  20.650326  10.842073
# 2021  407.205037  19.360577  195.715517  157.552711  22.339198  12.237033
#
#       Other  Per Capita
# 1891    NaN         NaN
# 1892    NaN         NaN
# 1893    NaN         NaN
# 1894    NaN         NaN
# 1895    NaN         NaN
# ...     ...         ...
# 2017    NaN    3.790490
# 2018    NaN    3.832385
# 2019    NaN    3.774956
# 2020    NaN    3.108821
# 2021    NaN    3.213801
#
# [131 rows x 8 columns]

# %%
def getDataCountry(country = "Mexico", dataCO2 = pd.read_csv('GCB2022v27_MtCO2_flat.csv')):
    
    dataCountry = dataCO2[dataCO2["Country"] == country]
    columns = dataCountry.columns
    year = dataCountry["Year"].values
    data = dataCountry[columns[3:]].set_index(year)
    
    return data[data["Total"] != 0.0]

# %%
getDataCountry()
# Out:
#            Total       Coal         Oil         Gas     Cement    Flaring  \
# 1891    0.520288   0.520288    0.000000    0.000000        NaN   0.000000
# 1892    0.578912   0.578912    0.000000    0.000000        NaN   0.000000
# 1893    0.531280   0.531280    0.000000    0.000000        NaN   0.000000
# 1894    0.538608   0.538608    0.000000    0.000000        NaN   0.000000
# 1895    0.494640   0.494640    0.000000    0.000000        NaN   0.000000
# ...          ...        ...         ...         ...        ...        ...
# 2017  465.620953  48.529680  245.839744  143.251408  20.876858   7.123264
# 2018  475.268909  47.313232  233.825488  165.905920  20.863843   7.360426
# 2019  472.191499  45.268010  241.897149  157.098863  19.497632   8.429845
# 2020  391.706208  20.011074  190.678139  149.524596  20.650326  10.842073
# 2021  407.205037  19.360577  195.715517  157.552711  22.339198  12.237033
#
#       Other  Per Capita
# 1891    NaN         NaN
# 1892    NaN         NaN
# 1893    NaN         NaN
# 1894    NaN         NaN
# 1895    NaN         NaN
# ...     ...         ...
# 2017    NaN    3.790490
# 2018    NaN    3.832385
# 2019    NaN    3.774956
# 2020    NaN    3.108821
# 2021    NaN    3.213801
#
# [131 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# %%
totalUSA = getDataCountry(country = "USA")["Total"].values
totalMEX = getDataCountry(country = "Mexico")["Total"].values

# %%
yearUSA = getDataCountry(country = "USA").index
yearMEX = getDataCountry(country = "Mexico").index

# %%
plt.plot(yearUSA, totalUSA)
plt.plot(yearMEX, totalMEX)

# %%
plt.plot(yearMEX, totalMEX)
